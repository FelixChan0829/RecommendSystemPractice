# %%
import random
import math
import time
from tqdm import tqdm

# %%
def timmer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        stop_time = time.time()
        print('Func %s, run time: %s' % (func.__name__, stop_time - start_time))
        return res
    return wrapper

# %%
class DataSet():
    def __init__(self, fp):
        self.data = self.load(fp)

    def load(self, fp):
        data = []
        for i in open(fp):
            data.append(tuple(map(int, i.strip().split('::')[0:2])))
        return data

    def split_data(self, M, k, seed=1):
        '''
        :params: data, 加载的所有(user, item)数据条目
        :params: M, 划分的数目，最后需要取M折的平均
        :params: k, 本次是第几次划分，k~[0, M)
        :params: seed, random的种子数，对于不同的k应设置成一样的
        :return: train, test
        每次实验选取不同的k(0<= k <= M-1)和相同的随机数种子seed，进行M次实验就可以得到M个不同的训练集和测试集，分别进行实验，用M次实验的
        平均值作为最后的评测指标。这样做主要是为了防止过拟合
        '''
        train, test = [], []
        random.seed(seed)
        for user, item in self.data:
            # random.randint 为左闭右闭
            # np.random.randint 为左闭右开
            if random.randint(0, M - 1) == k:
                test.append([user, item])
            else:
                train.append([user, item])
        #print(test)
        #print(train)

        def convert_dict(data):
            dict = {}
            for user, item in data:
                if user not in dict.keys():
                    dict[user] = []
                    dict[user].append(item)
                else:
                    dict[user].append(item)
            return dict

        return convert_dict(train), convert_dict(test)

# %%
class Metric():
    def __init__(self, train, test, GetRecommendation):
        '''
        :params: train, 训练数据
        :params: test, 测试数据
        :params: GetRecommendation, 为某个用户获取推荐物品的接口函数
        '''
        self.train = train
        self.test = test
        self.GetRecommendation = GetRecommendation
        self.recs = self.get_recommandation()

    #为test中的每一个用户进行推荐
    def get_recommandation(self):
        recs={}
        for user in self.test.keys():
            rank=self.GetRecommendation(user)
            recs[user]=rank
        return recs    
    
    #推荐系统常见问题：TopN 推荐是对训练集中的用户进行推荐，还是对测试集中的用户进行推荐？
    #https://blog.csdn.net/qiqi123i/article/details/104925774
    def precision(self):
        hit, all = 0, 0
        for user in self.test.keys():
            tu = self.test[user]
            rank = self.recs[user]
            for item, score in rank:
                if item in tu:
                    hit += 1
            all += len(rank)
        return hit / (all * 1.0)

    def recall(self):
        hit, all = 0, 0
        for user in self.test.keys():
            tu = self.test[user]
            rank = self.recs[user]
            for item, score in rank:
                if item in tu:
                    hit += 1
            all += len(tu)
        return hit / (all * 1.0)

    def coverage(self):
        recommend_items = set()
        all_items = set()
        for user in self.test.keys():
            for item in self.train[user]:
                all_items.add(item)
            rank = self.recs[user]
            for item, score in rank:
                recommend_items.add(item)
        return len(recommend_items) / (len(all_items) * 1.0)

    
       # 定义新颖度指标计算方式
    def popularity(self):
        # 计算物品的流行度
        item_pop = {}
        for user in self.train.keys():
            for item in self.train[user]:
                if item not in item_pop:
                    item_pop[item] = 0
                item_pop[item] += 1

        num, pop = 0, 0
        for user in self.test.keys():
            rank = self.recs[user]
            for item, score in rank:
                # 取对数，防止因长尾问题带来的被流行物品所主导
                pop += math.log(1 + item_pop[item])
                num += 1
        return round(pop / num, 6)
    
    def eval(self):
        metric = {'Precision': self.precision(),
                  'Recall': self.recall(),
                  'Coverage': self.coverage(),
                  'Popularity': self.popularity()}
        print('Metric:', metric)
        return metric

# %%
# 1. 基于物品余弦相似度的推荐
def ItemCF(train, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似物品数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算物品相似度矩阵
    sim = {}
    num = {}
    for user in train:
        items = train[user]
        for i in range(len(items)):
            u = items[i]
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for j in range(len(items)):
                if j == i: continue
                v = items[j]
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_item_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set(train[user])
        for item in train[user]:
            for u, _ in sorted_item_sim[item][:K]:
                if u not in seen_items:
                    if u not in items:
                        items[u] = 0
                    items[u] += sim[item][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    
    #返回接口函数
    return GetRecommendation

# %%
# 2. 基于改进的物品余弦相似度的推荐
def ItemIUF(train, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似物品数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    ''' 
    # 计算物品相似度矩阵
    sim = {}
    num = {}
    for user in train:
        items = train[user]
        for i in range(len(items)):
            u = items[i]
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for j in range(len(items)):
                if j == i: continue
                v = items[j]
                if v not in sim[u]:
                    sim[u][v] = 0
                # 相比ItemCF，主要是改进了这里
                sim[u][v] += 1 / math.log(1 + len(items))
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_item_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set(train[user])
        for item in train[user]:
            for u, _ in sorted_item_sim[item][:K]:
                # 要去掉用户见过的
                if u not in seen_items:
                    if u not in items:
                        items[u] = 0
                    items[u] += sim[item][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation

# %%
# 3. 基于归一化的物品余弦相似度的推荐
def ItemCF_Norm(train, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似物品数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算物品相似度矩阵
    sim = {}
    num = {}
    for user in train:
        items = train[user]
        for i in range(len(items)):
            u = items[i]
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for j in range(len(items)):
                if j == i: continue
                v = items[j]
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
            
    # 对相似度矩阵进行按行归一化
    for u in sim:
        s = 0
        for v in sim[u]:
            s += sim[u][v]
        if s > 0:
            for v in sim[u]:
                sim[u][v] /= s
    
    # 按照相似度排序
    sorted_item_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set(train[user])
        for item in train[user]:
            for u, _ in sorted_item_sim[item][:K]:
                if u not in seen_items:
                    if u not in items:
                        items[u] = 0
                    items[u] += sim[item][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation

# %%
class Experiment():
    
    def __init__(self, M, K, N, fp='/Users/felix/PycharmProjects/RecommendSystemPractice/dataSet/ml-1m/ratingsTest.dat', rt='ItemCF'):
        '''
        :params: M, 进行多少次实验
        :params: K, TopK相似物品的个数
        :params: N, TopN推荐物品的个数
        :params: fp, 数据文件路径
        :params: rt, 推荐算法类型
        '''
        self.M = M
        self.K = K
        self.N = N
        self.fp = fp
        self.rt = rt
        self.alg = {'ItemCF': ItemCF, 'ItemIUF': ItemIUF, 'ItemCF-Norm': ItemCF_Norm}
    
    # 定义单次实验
    @timmer
    def worker(self, train, test):
        '''
        :params: train, 训练数据集
        :params: test, 测试数据集
        :return: 各指标的值
        '''
        getRecommendation = self.alg[self.rt](train, self.K, self.N)
        metric = Metric(train, test, getRecommendation)
        return metric.eval()
    
    # 多次实验取平均
    @timmer
    def run(self):
        metrics = {'Precision': 0, 'Recall': 0, 
                   'Coverage': 0, 'Popularity': 0}
        dataset = DataSet(self.fp)
        for ii in range(self.M):
            train, test = dataset.split_data(self.M, ii)
            print('Experiment {}:'.format(ii))
            metric = self.worker(train, test)
            metrics = {k: metrics[k]+metric[k] for k in metrics}
        metrics = {k: metrics[k] / self.M for k in metrics}
        print('Average Result (M={}, K={}, N={}): {}'.format(\
                              self.M, self.K, self.N, metrics))

# %%
# 1. ItemCF实验
M, N = 8, 10
for K in [5, 10, 20, 40, 80, 160]:
    cf_exp = Experiment(M, K, N, rt='ItemCF')
    cf_exp.run()
# Out:
# Experiment 0:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.084070796460177, 'Popularity': 0.888371}
# Func worker, run time: 0.016270875930786133
# Experiment 1:
# Metric: {'Precision': 0.05555555555555555, 'Recall': 0.025, 'Coverage': 0.06465517241379311, 'Popularity': 0.873354}
# Func worker, run time: 0.0159451961517334
# Experiment 2:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.06306306306306306, 'Popularity': 0.936426}
# Func worker, run time: 0.015272378921508789
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.10407239819004525, 'Popularity': 0.922911}
# Func worker, run time: 0.01519012451171875
# Experiment 4:
# Metric: {'Precision': 0.07142857142857142, 'Recall': 0.05, 'Coverage': 0.09170305676855896, 'Popularity': 0.89588}
# Func worker, run time: 0.014463186264038086
# Experiment 5:
# Metric: {'Precision': 0.034482758620689655, 'Recall': 0.02857142857142857, 'Coverage': 0.09012875536480687, 'Popularity': 0.898809}
# Func worker, run time: 0.014521121978759766
# Experiment 6:
# Metric: {'Precision': 0.043478260869565216, 'Recall': 0.025, 'Coverage': 0.08, 'Popularity': 0.834179}
# Func worker, run time: 0.013787031173706055
# Experiment 7:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.09401709401709402, 'Popularity': 0.868849}
# Func worker, run time: 0.01487278938293457
# Average Result (M=8, K=5, N=10): {'Precision': 0.025618143309297733, 'Recall': 0.016071428571428573, 'Coverage': 0.08396379203469227, 'Popularity': 0.889847375}
# Func run, run time: 0.1246500015258789
# Experiment 0:
# Metric: {'Precision': 0.025, 'Recall': 0.025, 'Coverage': 0.11504424778761062, 'Popularity': 0.866773}
# Func worker, run time: 0.013760566711425781
# Experiment 1:
# Metric: {'Precision': 0.04878048780487805, 'Recall': 0.05, 'Coverage': 0.11637931034482758, 'Popularity': 0.852649}
# Func worker, run time: 0.01470494270324707
# Experiment 2:
# Metric: {'Precision': 0.03125, 'Recall': 0.03225806451612903, 'Coverage': 0.0990990990990991, 'Popularity': 0.875848}
# Func worker, run time: 0.014010190963745117
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.11312217194570136, 'Popularity': 0.907936}
# Func worker, run time: 0.014384031295776367
# Experiment 4:
# Metric: {'Precision': 0.06976744186046512, 'Recall': 0.075, 'Coverage': 0.1222707423580786, 'Popularity': 0.885687}
# Func worker, run time: 0.013666152954101562
# Experiment 5:
# Metric: {'Precision': 0.07894736842105263, 'Recall': 0.08571428571428572, 'Coverage': 0.10300429184549356, 'Popularity': 0.847}
# Func worker, run time: 0.014419078826904297
# Experiment 6:
# Metric: {'Precision': 0.02631578947368421, 'Recall': 0.025, 'Coverage': 0.11555555555555555, 'Popularity': 0.810519}
# Func worker, run time: 0.016408920288085938
# Experiment 7:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.10256410256410256, 'Popularity': 0.76939}
# Func worker, run time: 0.01566624641418457
# Average Result (M=8, K=10, N=10): {'Precision': 0.035007635945009996, 'Recall': 0.03662154377880185, 'Coverage': 0.1108799401875586, 'Popularity': 0.8519752500000002}
# Func run, run time: 0.12118101119995117
# Experiment 0:
# Metric: {'Precision': 0.023255813953488372, 'Recall': 0.025, 'Coverage': 0.10176991150442478, 'Popularity': 0.741506}
# Func worker, run time: 0.014387845993041992
# Experiment 1:
# Metric: {'Precision': 0.044444444444444446, 'Recall': 0.05, 'Coverage': 0.11206896551724138, 'Popularity': 0.766388}
# Func worker, run time: 0.014806032180786133
# Experiment 2:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.12162162162162163, 'Popularity': 0.793182}
# Func worker, run time: 0.014211177825927734
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.14479638009049775, 'Popularity': 0.835902}
# Func worker, run time: 0.013563871383666992
# Experiment 4:
# Metric: {'Precision': 0.022727272727272728, 'Recall': 0.025, 'Coverage': 0.10480349344978165, 'Popularity': 0.743084}
# Func worker, run time: 0.013977766036987305
# Experiment 5:
# Metric: {'Precision': 0.023255813953488372, 'Recall': 0.02857142857142857, 'Coverage': 0.09871244635193133, 'Popularity': 0.734816}
# Func worker, run time: 0.014500141143798828
# Experiment 6:
# Metric: {'Precision': 0.021739130434782608, 'Recall': 0.025, 'Coverage': 0.12444444444444444, 'Popularity': 0.782425}
# Func worker, run time: 0.013715982437133789
# Experiment 7:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.09829059829059829, 'Popularity': 0.728126}
# Func worker, run time: 0.030421972274780273
# Average Result (M=8, K=20, N=10): {'Precision': 0.016927809439184566, 'Recall': 0.019196428571428573, 'Coverage': 0.11331348265881766, 'Popularity': 0.7656786250000001}
# Func run, run time: 0.13364315032958984
# Experiment 0:
# Metric: {'Precision': 0.02, 'Recall': 0.025, 'Coverage': 0.11061946902654868, 'Popularity': 0.693147}
# Func worker, run time: 0.014168977737426758
# Experiment 1:
# Metric: {'Precision': 0.0425531914893617, 'Recall': 0.05, 'Coverage': 0.11637931034482758, 'Popularity': 0.754644}
# Func worker, run time: 0.01477813720703125
# Experiment 2:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.13513513513513514, 'Popularity': 0.78568}
# Func worker, run time: 0.014559030532836914
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.11312217194570136, 'Popularity': 0.693147}
# Func worker, run time: 0.014300346374511719
# Experiment 4:
# Metric: {'Precision': 0.022222222222222223, 'Recall': 0.025, 'Coverage': 0.1091703056768559, 'Popularity': 0.741974}
# Func worker, run time: 0.014640092849731445
# Experiment 5:
# Metric: {'Precision': 0.021739130434782608, 'Recall': 0.02857142857142857, 'Coverage': 0.11158798283261803, 'Popularity': 0.732098}
# Func worker, run time: 0.01629805564880371
# Experiment 6:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.12, 'Popularity': 0.709366}
# Func worker, run time: 0.015002012252807617
# Experiment 7:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.10683760683760683, 'Popularity': 0.693147}
# Func worker, run time: 0.015787124633789062
# Average Result (M=8, K=40, N=10): {'Precision': 0.013314318018295817, 'Recall': 0.016071428571428573, 'Coverage': 0.11535649772491169, 'Popularity': 0.725400375}
# Func run, run time: 0.1235499382019043
# Experiment 0:
# Metric: {'Precision': 0.02, 'Recall': 0.025, 'Coverage': 0.08849557522123894, 'Popularity': 0.693147}
# Func worker, run time: 0.014586210250854492
# Experiment 1:
# Metric: {'Precision': 0.04, 'Recall': 0.05, 'Coverage': 0.12931034482758622, 'Popularity': 0.693147}
# Func worker, run time: 0.016308069229125977
# Experiment 2:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.13513513513513514, 'Popularity': 0.693147}
# Func worker, run time: 0.016041278839111328
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.09502262443438914, 'Popularity': 0.70701}
# Func worker, run time: 0.015294313430786133
# Experiment 4:
# Metric: {'Precision': 0.02, 'Recall': 0.025, 'Coverage': 0.13100436681222707, 'Popularity': 0.693147}
# Func worker, run time: 0.016227006912231445
# Experiment 5:
# Metric: {'Precision': 0.02, 'Recall': 0.02857142857142857, 'Coverage': 0.08583690987124463, 'Popularity': 0.693147}
# Func worker, run time: 0.016419172286987305
# Experiment 6:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.08888888888888889, 'Popularity': 0.693147}
# Func worker, run time: 0.015516281127929688
# Experiment 7:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.09401709401709402, 'Popularity': 0.709366}
# Func worker, run time: 0.016257762908935547
# Average Result (M=8, K=80, N=10): {'Precision': 0.0125, 'Recall': 0.016071428571428573, 'Coverage': 0.1059638674009755, 'Popularity': 0.69690725}
# Func run, run time: 0.13081693649291992
# Experiment 0:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.1592920353982301, 'Popularity': 0.959441}
# Func worker, run time: 0.01554107666015625
# Experiment 1:
# Metric: {'Precision': 0.04, 'Recall': 0.05, 'Coverage': 0.14224137931034483, 'Popularity': 0.862129}
# Func worker, run time: 0.01714301109313965
# Experiment 2:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.16216216216216217, 'Popularity': 0.979579}
# Func worker, run time: 0.016849756240844727
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.1583710407239819, 'Popularity': 0.914183}
# Func worker, run time: 0.01719188690185547
# Experiment 4:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.14410480349344978, 'Popularity': 0.87495}
# Func worker, run time: 0.017757892608642578
# Experiment 5:
# Metric: {'Precision': 0.02, 'Recall': 0.02857142857142857, 'Coverage': 0.11587982832618025, 'Popularity': 0.842513}
# Func worker, run time: 0.0182039737701416
# Experiment 6:
# Metric: {'Precision': 0.02, 'Recall': 0.025, 'Coverage': 0.1688888888888889, 'Popularity': 0.975659}
# Func worker, run time: 0.016904115676879883
# Experiment 7:
# Metric: {'Precision': 0.06, 'Recall': 0.08823529411764706, 'Coverage': 0.14102564102564102, 'Popularity': 0.953687}
# Func worker, run time: 0.018555879592895508
# Average Result (M=8, K=160, N=10): {'Precision': 0.0175, 'Recall': 0.023975840336134452, 'Coverage': 0.14899572241610987, 'Popularity': 0.9202676249999999}
# Func run, run time: 0.14354300498962402

# %%
# 2. ItemIUF实验

M, N = 8, 10
K = 10 # 与书中保持一致
iuf_exp = Experiment(M, K, N, rt='ItemIUF')
iuf_exp.run()
# Out:
# Experiment 0:
# Metric: {'Precision': 0.05128205128205128, 'Recall': 0.05, 'Coverage': 0.11504424778761062, 'Popularity': 0.860828}
# Func worker, run time: 0.02000904083251953
# Experiment 1:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.06896551724137931, 'Popularity': 0.722109}
# Func worker, run time: 0.021938323974609375
# Experiment 2:
# Metric: {'Precision': 0.027777777777777776, 'Recall': 0.03225806451612903, 'Coverage': 0.13963963963963963, 'Popularity': 0.889336}
# Func worker, run time: 0.020570039749145508
# Experiment 3:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.16289592760180996, 'Popularity': 0.906778}
# Func worker, run time: 0.01935291290283203
# Experiment 4:
# Metric: {'Precision': 0.05555555555555555, 'Recall': 0.05, 'Coverage': 0.11353711790393013, 'Popularity': 0.794513}
# Func worker, run time: 0.019886016845703125
# Experiment 5:
# Metric: {'Precision': 0.046511627906976744, 'Recall': 0.05714285714285714, 'Coverage': 0.12446351931330472, 'Popularity': 0.860138}
# Func worker, run time: 0.021999835968017578
# Experiment 6:
# Metric: {'Precision': 0.05, 'Recall': 0.05, 'Coverage': 0.1511111111111111, 'Popularity': 0.83506}
# Func worker, run time: 0.01927495002746582
# Experiment 7:
# Metric: {'Precision': 0.0, 'Recall': 0.0, 'Coverage': 0.12393162393162394, 'Popularity': 0.834588}
# Func worker, run time: 0.021333932876586914
# Average Result (M=8, K=10, N=10): {'Precision': 0.028890876565295168, 'Recall': 0.029925115207373273, 'Coverage': 0.12494858806630117, 'Popularity': 0.83791875}
# Func run, run time: 0.16918087005615234

# %% [markdown]
# #
